# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd drive/MyDrive/Colab_Notebooks/mysite
# Out:
# [Errno 2] No such file or directory: 'drive/MyDrive/Colab_Notebooks'
# /content/drive/MyDrive/Colab_Notebooks/mysite

# %%
# !pip install django
# Out:
# Requirement already satisfied: django in /usr/local/lib/python3.7/dist-packages (3.2.13)
# Requirement already satisfied: asgiref<4,>=3.3.2 in /usr/local/lib/python3.7/dist-packages (from django) (3.5.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from django) (2022.1)
# Requirement already satisfied: sqlparse>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from django) (0.4.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from asgiref<4,>=3.3.2->django) (4.2.0)

# %%
#!django-admin startproject mysite
# Out:
# CommandError: '/content/drive/MyDrive/Colab_Notebooks/mysite' already exists

# %%
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(8000)"))
# Out:
# https://jh158miw7b-496ff2e9c6d22116-8000-colab.googleusercontent.com/

# %%
# !python manage.py runserver 8000
# Out:
# Watching for file changes with StatReloader
# Performing system checks...
#
# System check identified no issues (0 silenced).
# May 18, 2022 - 11:52:16
# Django version 3.2.13, using settings 'mysite.settings'
# Starting development server at http://127.0.0.1:8000/
# Quit the server with CONTROL-C.
# [18/May/2022 11:52:20] "GET /poll/index/ HTTP/1.1" 200 1878
# [18/May/2022 11:52:20] "GET /static/base.css HTTP/1.1" 200 250
# [18/May/2022 11:52:20] "GET /static/None.jpg HTTP/1.1" 200 3546
# Not Found: /favicon.ico
# [18/May/2022 11:52:20] "GET /favicon.ico HTTP/1.1" 404 2226
# 100% 100/100 [00:47<00:00,  2.09it/s]
# 100% 27/27 [00:33<00:00,  1.23s/it]
# [18/May/2022 11:54:26] "POST /poll/index/ HTTP/1.1" 200 1896
# [18/May/2022 11:54:26] "GET /static/base.css HTTP/1.1" 200 250
# [18/May/2022 11:54:26] "GET /static/result.jpg HTTP/1.1" 200 14487
# Not Found: /favicon.ico
# [18/May/2022 11:54:26] "GET /favicon.ico HTTP/1.1" 404 2226
# 100% 100/100 [00:48<00:00,  2.07it/s]
# 100% 27/27 [00:33<00:00,  1.24s/it]
# [18/May/2022 11:56:19] "POST /poll/index/ HTTP/1.1" 200 1898
# [18/May/2022 11:56:20] "GET /static/base.css HTTP/1.1" 200 250
# [18/May/2022 11:56:20] "GET /static/result.jpg HTTP/1.1" 200 13121
# Not Found: /favicon.ico
# [18/May/2022 11:56:20] "GET /favicon.ico HTTP/1.1" 404 2226

# %%
# %cd mysite
# Out:
# /content/drive/My Drive/Colab_Notebooks/mysite

# %%
#!python manage.py startapp polls
# Out:
# CommandError: 'polls' conflicts with the name of an existing Python module and cannot be used as an app name. Please try another name.

# %%
# !python manage.py makemigrations
# !python manage.py migrate
# Out:
# Migrations for 'polls':
#   polls/migrations/0004_delete_image.py
#     - Delete model Image
# Operations to perform:
#   Apply all migrations: admin, auth, contenttypes, polls, sessions
# Running migrations:
#   Applying polls.0004_delete_image... OK

# %%
# Run this line in Colab to install the package if it is
# not already installed.
# !pip install git+https://github.com/openai/glide-text2im
# Out:
# Collecting git+https://github.com/openai/glide-text2im
#   Cloning https://github.com/openai/glide-text2im to /tmp/pip-req-build-bygfet4m
#   Running command git clone -q https://github.com/openai/glide-text2im /tmp/pip-req-build-bygfet4m
# Requirement already satisfied: Pillow in /usr/local/lib/python3.7/dist-packages (from glide-text2im==0.0.0) (7.1.2)
# Requirement already satisfied: attrs in /usr/local/lib/python3.7/dist-packages (from glide-text2im==0.0.0) (21.4.0)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from glide-text2im==0.0.0) (1.11.0+cu113)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from glide-text2im==0.0.0) (3.7.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from glide-text2im==0.0.0) (2.23.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from glide-text2im==0.0.0) (4.64.0)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.3 MB/s
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from glide-text2im==0.0.0) (2019.12.20)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from glide-text2im==0.0.0) (1.21.6)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from ftfy->glide-text2im==0.0.0) (0.2.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->glide-text2im==0.0.0) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->glide-text2im==0.0.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->glide-text2im==0.0.0) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->glide-text2im==0.0.0) (2021.10.8)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->glide-text2im==0.0.0) (4.2.0)
# Building wheels for collected packages: glide-text2im
#   Building wheel for glide-text2im (setup.py) ... done
#   Created wheel for glide-text2im: filename=glide_text2im-0.0.0-py3-none-any.whl size=1953663 sha256=1662817fcf87fa604d1c002236248aad44a3f0f68c85e3453fbecd187b6c0da0
#   Stored in directory: /tmp/pip-ephem-wheel-cache-wnzllixz/wheels/b4/36/07/46711fd6462da277046c6720504e61546b6e32adc0293abc96
# Successfully built glide-text2im
# Installing collected packages: ftfy, glide-text2im
# Successfully installed ftfy-6.1.1 glide-text2im-0.0.0

# %%
'''from PIL import Image
#from IPython.display import display
import torch as th
import torch.nn as nn

from glide_text2im.clip.model_creation import create_clip_model
from glide_text2im.download import load_checkpoint
from glide_text2im.model_creation import (
    create_model_and_diffusion,
    model_and_diffusion_defaults,
    model_and_diffusion_defaults_upsampler,
)
from glide_text2im.tokenizer.simple_tokenizer import SimpleTokenizer

# This notebook supports both CPU and GPU.
# On CPU, generating one sample may take on the order of 20 minutes.
# On a GPU, it should be under a minute.

has_cuda = th.cuda.is_available()
device = th.device('cpu' if not has_cuda else 'cuda')

# Create base model.
options = model_and_diffusion_defaults()
options['use_fp16'] = has_cuda
options['timestep_respacing'] = '100' # use 100 diffusion steps for fast sampling
model, diffusion = create_model_and_diffusion(**options)
model.eval()
if has_cuda:
    model.convert_to_fp16()
print("here")
model.to(device)
model.load_state_dict(load_checkpoint('base', device))
print('total base parameters', sum(x.numel() for x in model.parameters()))

# Create upsampler model.
options_up = model_and_diffusion_defaults_upsampler()
options_up['use_fp16'] = has_cuda
options_up['timestep_respacing'] = 'fast27' # use 27 diffusion steps for very fast sampling
model_up, diffusion_up = create_model_and_diffusion(**options_up)
model_up.eval()
if has_cuda:
    model_up.convert_to_fp16()
print("here")
model_up.to(device)
model_up.load_state_dict(load_checkpoint('upsample', device))
print('total upsampler parameters', sum(x.numel() for x in model_up.parameters()))

# Create CLIP model.
clip_model = create_clip_model(device=device)
print("here")
clip_model.image_encoder.load_state_dict(load_checkpoint('clip/image-enc', device))
clip_model.text_encoder.load_state_dict(load_checkpoint('clip/text-enc', device))'''
# Out:
# here
# total base parameters 385030726
# here
# total upsampler parameters 398361286
# here
# <All keys matched successfully>

# %%
# !python save_image.py
# Out:
# __main__
# 100% 100/100 [00:48<00:00,  2.07it/s]
# 100% 27/27 [00:33<00:00,  1.24s/it]
