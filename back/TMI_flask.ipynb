# %%
# !pip install --upgrade diffusers transformers scipy+++
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 503 kB 19.5 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 52.4 MB/s
# ...
#      |████████████████████████████████| 33.8 MB 253 kB/s
# ...
#      |████████████████████████████████| 182 kB 82.2 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 52.4 MB/s
# ...
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.7.3
#     Uninstalling scipy-1.7.3:
#       Successfully uninstalled scipy-1.7.3
# ...

# %%
# !huggingface-cli login
#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
#토큰 입력란 나오면 위에 문자 복사해서 붙여넣고 y누르면 됨
#빨간글씨 5줄 뜨는데 맨 밑에 Login successful 만 나오면 된거야
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` now requires a token generated from https://huggingface.co/settings/tokens .
#
# Token:
# Add token as git credential? (Y/n) y
# Token is valid.
# Cannot authenticate through git-credential as no helper is defined on your machine.
# You might have to re-authenticate when pushing to the Hugging Face Hub.
# ...

# %%
import os, sys
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls
# Out:
# drive  sample_data

# %%
# !pip install pymongo[srv]

# !pip install pyngrok==4.1.1
# !pip install flask_ngrok

# !pip install boto3

# !pip install sklearn
# !pip install keybert


# !pip install flask_cors

#!pip install huggingface_hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Created wheel for pyngrok: filename=pyngrok-4.1.1-py3-none-any.whl size=15982 sha256=fc22e7eaaaa63ee0be4846261d0e77198d448ca9a751b334767f0c05ca353ba6
#   Stored in directory: /root/.cache/pip/wheels/5e/0a/51/8cb053ccd84481dd3233eba4cdb608bc7a885fd8ca418c0806
# Successfully built pyngrok
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 132 kB 29.7 MB/s
# ...
#      |████████████████████████████████| 79 kB 8.9 MB/s
# ...
#      |████████████████████████████████| 10.3 MB 76.5 MB/s
# ...
#      |████████████████████████████████| 140 kB 76.3 MB/s
# ...
#   Attempting uninstall: urllib3
# ...

# %%
#이 부분 아마 공유드라이브? 로 바꿔야할거야
# %cd /content/drive/MyDrive/TMI_flask
# Out:
# /content/drive/MyDrive/TMI_flask

# %%
# !ngrok authtoken 
# !python app.py 
#실행시키고 쭉 기다리다가 127.0.0.1:5000/ 링크 한줄밑에
#Running on http://xxxx-xxx-xxx-xxx-xxx.ngrok.io 나오는데 이게 base_url이야
#그거 복사해서 쓰면 돼
# Out:
# Authtoken saved to configuration file: /root/.ngrok2/ngrok.yml
# Downloading: 100% 543/543 [00:00<00:00, 549kB/s]
# Fetching 16 files:   0% 0/16 [00:00<?, ?it/s]
# Downloading: 100% 342/342 [00:00<00:00, 324kB/s]
# Fetching 16 files:   6% 1/16 [00:01<00:27,  1.84s/it]
# Downloading: 100% 4.56k/4.56k [00:00<00:00, 2.82MB/s]
# Fetching 16 files:  19% 3/16 [00:03<00:15,  1.18s/it]
# Downloading:   0% 0.00/1.22G [00:00<?, ?B/s]
# Downloading:   1% 6.68M/1.22G [00:00<00:18, 66.8MB/s]
# Downloading:   1% 16.9M/1.22G [00:00<00:13, 87.8MB/s]
# Downloading:   2% 27.2M/1.22G [00:00<00:12, 94.6MB/s]
# Downloading:   3% 37.3M/1.22G [00:00<00:12, 97.3MB/s]
# Downloading:   4% 48.1M/1.22G [00:00<00:11, 101MB/s]
# Downloading:   5% 58.7M/1.22G [00:00<00:11, 103MB/s]
# Downloading:   6% 69.4M/1.22G [00:00<00:11, 104MB/s]
# Downloading:   7% 80.1M/1.22G [00:00<00:10, 105MB/s]
# Downloading:   7% 90.9M/1.22G [00:00<00:10, 106MB/s]
# Downloading:   8% 102M/1.22G [00:01<00:10, 107MB/s]
# ...
